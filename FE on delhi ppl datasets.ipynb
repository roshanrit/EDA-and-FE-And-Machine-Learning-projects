# %%
import pandas as pd
import numpy as np
#filling the missinf value by mean and mode 
#gender by one hot encoding
#state by target encoding
#built by frequency encoding
#height start as mean encoding
#dist by label encoding

# %%
sas=pd.read_csv("cleandata.csv",usecols=number)
sas
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd
# 0           16      17        122.0      183.0
# 1           19      20        153.0      183.0
# 2           19      20        153.0      183.0
# 3           24      25        153.0      183.0
# 4           21      22        153.0      183.0
# ...        ...     ...          ...        ...
# 2122        24      25        153.0      275.0
# 2123        15      16        153.0       31.0
# 2124        15      16        153.0      214.0
# 2125        58      59        153.0       31.0
# 2126         5       7          NaN        NaN
#
# [2127 rows x 4 columns]

# %%
sas.isnull().sum()
# Out:
# Name            567
# Gender          117
# Relative          2
# Address           0
# AgeStart          0
# AgeEnd            0
# HeightStart      33
# HeightEnd        33
# Built            12
# Date           2127
# Dist              0
# State           131
# dtype: int64

# %%
number=columns_to_use=['AgeStart', 'AgeEnd', 'HeightStart', 'HeightEnd']

# %%
from sklearn.impute import SimpleImputer
seg=SimpleImputer(strategy="mean")

# %%
sas=seg.fit_transform(sas)

# %%
a=pd.DataFrame(sas,columns=number)
a
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd
# 0         16.0    17.0        122.0      183.0
# 1         19.0    20.0        153.0      183.0
# 2         19.0    20.0        153.0      183.0
# 3         24.0    25.0        153.0      183.0
# 4         21.0    22.0        153.0      183.0
# ...        ...     ...          ...        ...
# 2122      24.0    25.0        153.0      275.0
# 2123      15.0    16.0        153.0       31.0
# 2124      15.0    16.0        153.0      214.0
# 2125      58.0    59.0        153.0       31.0
# 2126       5.0     7.0        153.0      183.0
#
# [2127 rows x 4 columns]

# %%
sas1=pd.read_csv("cleandata.csv",usecols=cat)
sas1
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                        NaN    Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL      NaN   SUMA N GHOSHAL
# 2124                     NaN    Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address         Built  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...  normalmedium
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...          thin
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...          thin
# ...

# %%
cat=columns_to_use=['Name', 'Gender', 'Relative', 'Address', 'Built', 'Dist', 'State']

# %%
from sklearn.impute import SimpleImputer
sem=SimpleImputer(strategy="most_frequent")

# %%
sas1=sem.fit_transform(sas1)

# %%
b=pd.DataFrame(sas1,columns=cat)
b
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                    Female     Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL     Male   SUMA N GHOSHAL
# 2124                 Female     Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address         Built  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...  normalmedium
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...          thin
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...          thin
# ...

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0        122.0      183.0                   JYOTI
# 1         19.0    20.0        153.0      183.0                ABHISHEK
# 2         19.0    20.0        153.0      183.0                 Female
# 3         24.0    25.0        153.0      183.0              JAIPRAKASH
# 4         21.0    22.0        153.0      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0        153.0      275.0                  MANOJ
# 2123      15.0    16.0        153.0       31.0           SAGARGHOSHAL
# 2124      15.0    16.0        153.0      214.0                 Female
# 2125      58.0    59.0        153.0       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0        153.0      183.0                  DEPTY
#
#       Gender          Relative  \
# 0     Female             GEETA
# 1       Male      MUKE SHKUMAR
# ...

# %%
c.nunique()
# Out:
# AgeStart         83
# AgeEnd           84
# HeightStart      17
# HeightEnd        24
# Name           1212
# Gender            2
# Relative       1776
# Address        2109
# Built             7
# Dist            174
# State            14
# dtype: int64

# %%
c["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
pd.get_dummies(c["Gender"],drop_first=True)
# Out:
#       Male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 2122     1
# 2123     1
# 2124     1
# 2125     1
# 2126     1
#
# [2127 rows x 1 columns]

# %%
c["Gender"]=c["Gender"].map({"Female":1, "Male":0})

# %%
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0        122.0      183.0                   JYOTI
# 1         19.0    20.0        153.0      183.0                ABHISHEK
# 2         19.0    20.0        153.0      183.0                 Female
# 3         24.0    25.0        153.0      183.0              JAIPRAKASH
# 4         21.0    22.0        153.0      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0        153.0      275.0                  MANOJ
# 2123      15.0    16.0        153.0       31.0           SAGARGHOSHAL
# 2124      15.0    16.0        153.0      214.0                 Female
# 2125      58.0    59.0        153.0       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0        153.0      183.0                  DEPTY
#
#       Gender          Relative  \
# 0          1             GEETA
# 1          0      MUKE SHKUMAR
# ...

# %%
d=c.groupby(["State"])["HeightEnd"].mean().sort_values().index
d
# Out:
# Index(['NORTH', 'SOUTH', 'WEST', 'CENTRAL', 'DEL', 'EAS', 'SOUT', 'DELH',
#        'NORT', 'DE', 'CENT', 'CENTRA', 'DELHI', 'D'],
#       dtype='object', name='State')

# %%
enumerate(d,0)

# %%
model={k:i for i,k in enumerate(d,0)}
model
# Out:
# {'NORTH': 0,
#  'SOUTH': 1,
#  'WEST': 2,
#  'CENTRAL': 3,
#  'DEL': 4,
#  'EAS': 5,
#  'SOUT': 6,
#  'DELH': 7,
#  'NORT': 8,
#  'DE': 9,
#  'CENT': 10,
#  'CENTRA': 11,
#  'DELHI': 12,
#  'D': 13}

# %%
c["State"]=c["State"].map(model)

# %%
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0        122.0      183.0                   JYOTI
# 1         19.0    20.0        153.0      183.0                ABHISHEK
# 2         19.0    20.0        153.0      183.0                 Female
# 3         24.0    25.0        153.0      183.0              JAIPRAKASH
# 4         21.0    22.0        153.0      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0        153.0      275.0                  MANOJ
# 2123      15.0    16.0        153.0       31.0           SAGARGHOSHAL
# 2124      15.0    16.0        153.0      214.0                 Female
# 2125      58.0    59.0        153.0       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0        153.0      183.0                  DEPTY
#
#       Gender          Relative  \
# 0          1             GEETA
# 1          0      MUKE SHKUMAR
# ...

# %%
a=c["Built"].value_counts().to_dict()
a
# Out:
# {'normalmedium': 1008,
#  'thin': 832,
#  'strong': 244,
#  'fat': 27,
#  'muscular': 11,
#  'veryfat': 4,
#  'verylanky': 1}

# %%
c["Built"]=c["Built"].map(a)

# %%
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0        122.0      183.0                   JYOTI
# 1         19.0    20.0        153.0      183.0                ABHISHEK
# 2         19.0    20.0        153.0      183.0                 Female
# 3         24.0    25.0        153.0      183.0              JAIPRAKASH
# 4         21.0    22.0        153.0      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0        153.0      275.0                  MANOJ
# 2123      15.0    16.0        153.0       31.0           SAGARGHOSHAL
# 2124      15.0    16.0        153.0      214.0                 Female
# 2125      58.0    59.0        153.0       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0        153.0      183.0                  DEPTY
#
#       Gender          Relative  \
# 0          1             GEETA
# 1          0      MUKE SHKUMAR
# ...

# %%
e=c.groupby(["HeightStart"])["AgeStart"].mean().to_dict()
e
# Out:
# {3.0: 11.0,
#  4.0: 15.0,
#  5.0: 26.22222222222222,
#  31.0: 1.25,
#  61.0: 3.56,
#  92.0: 8.083333333333334,
#  122.0: 16.505703422053234,
#  150.0: 24.0,
#  152.0: 19.5,
#  153.0: 28.28453850676073,
#  163.0: 23.0,
#  170.0: 19.0,
#  183.0: 33.84444444444444,
#  336.0: 11.0,
#  519.0: 17.0,
#  1860.0: 10.0,
#  4664.0: 26.2}

# %%
c["HeightStart"]=c["HeightStart"].map(e)

# %%
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0    16.505703      183.0                   JYOTI
# 1         19.0    20.0    28.284539      183.0                ABHISHEK
# 2         19.0    20.0    28.284539      183.0                 Female
# 3         24.0    25.0    28.284539      183.0              JAIPRAKASH
# 4         21.0    22.0    28.284539      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0    28.284539      275.0                  MANOJ
# 2123      15.0    16.0    28.284539       31.0           SAGARGHOSHAL
# 2124      15.0    16.0    28.284539      214.0                 Female
# 2125      58.0    59.0    28.284539       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0    28.284539      183.0                  DEPTY
#
#       Gender          Relative  \
# 0          1             GEETA
# 1          0      MUKE SHKUMAR
# ...

# %%
c.nunique()
# Out:
# AgeStart         83
# AgeEnd           84
# HeightStart      16
# HeightEnd        24
# Name           1212
# Gender            2
# Relative       1776
# Address        2109
# Built             7
# Dist            174
# State            14
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
c["Dist"]=lab.fit_transform(c["Dist"])

# %%
c
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd                    Name  \
# 0         16.0    17.0    16.505703      183.0                   JYOTI
# 1         19.0    20.0    28.284539      183.0                ABHISHEK
# 2         19.0    20.0    28.284539      183.0                 Female
# 3         24.0    25.0    28.284539      183.0              JAIPRAKASH
# 4         21.0    22.0    28.284539      183.0                  SADDAM
# ...        ...     ...          ...        ...                     ...
# 2122      24.0    25.0    28.284539      275.0                  MANOJ
# 2123      15.0    16.0    28.284539       31.0           SAGARGHOSHAL
# 2124      15.0    16.0    28.284539      214.0                 Female
# 2125      58.0    59.0    28.284539       31.0  CHANDER NARYAN PANDEY
# 2126       5.0     7.0    28.284539      183.0                  DEPTY
#
#       Gender          Relative  \
# 0          1             GEETA
# 1          0      MUKE SHKUMAR
# ...
