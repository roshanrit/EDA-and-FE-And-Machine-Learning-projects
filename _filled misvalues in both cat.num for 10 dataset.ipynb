# %%
import pandas as pd    #1. titanic missing handle datasets

# %%
#numerical dat set and add variable in numbers
ros=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/Feature-Engineering-Live-sessions/master/titanic.csv",usecols=number)
ros
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#catgorical datasets in a variables
ros1=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/Feature-Engineering-Live-sessions/master/titanic.csv",usecols=cat)
ros1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#converting numbers in to list
number=columns_to_use=["PassengerId","Survived","Pclass","Age","SibSp","Parch","Fare"]

# %%
#converting catgories into list
cat=columns_to_use=["Name","Sex","Ticket","Cabin","Embarked"]

# %%
#filling all the numbers with mean,median,mode
from sklearn.impute import SimpleImputer
obj=SimpleImputer(strategy="mean")

# %%
ros=obj.fit_transform(ros)

# %%
#converting transformed into data frames
a=pd.DataFrame(ros,columns=number)
a
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0            1.0       0.0     3.0  22.000000    1.0    0.0   7.2500
# 1            2.0       1.0     1.0  38.000000    1.0    0.0  71.2833
# 2            3.0       1.0     3.0  26.000000    0.0    0.0   7.9250
# 3            4.0       1.0     1.0  35.000000    1.0    0.0  53.1000
# 4            5.0       0.0     3.0  35.000000    0.0    0.0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886        887.0       0.0     2.0  27.000000    0.0    0.0  13.0000
# 887        888.0       1.0     1.0  19.000000    0.0    0.0  30.0000
# 888        889.0       0.0     3.0  29.699118    1.0    2.0  23.4500
# 889        890.0       1.0     1.0  26.000000    0.0    0.0  30.0000
# 890        891.0       0.0     3.0  32.000000    0.0    0.0   7.7500
#
# [891 rows x 7 columns]

# %%
ros1=pd.read_csv("https://raw.githubusercontent.com/krishnaik06/Feature-Engineering-Live-sessions/master/titanic.csv",usecols=cat)
ros1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
ros1.isnull().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
ros1["Cabin"]=ros1["Cabin"].fillna(ros1["Cabin"].mode()[0])

# %%
ros1.isnull().sum()
# Out:
# Name        0
# Sex         0
# Ticket      0
# Cabin       0
# Embarked    2
# dtype: int64

# %%
ros1["Embarked"].mode()[0]
# Out:
# 'S'

# %%
ros1["Embarked"]=ros1["Embarked"].fillna(ros1["Embarked"].mode()[0])

# %%
ros1.isnull().sum()
# Out:
# Name        0
# Sex         0
# Ticket      0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
b=pd.DataFrame(ros1,columns=cat)
b
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket    Cabin Embarked
# 0           A/5 21171  B96 B98        S
# 1            PC 17599      C85        C
# 2    STON/O2. 3101282  B96 B98        S
# 3              113803     C123        S
# ...

# %%
#concatinating the all columns after filling the missing values
c=pd.concat([a,b],axis=1)
c
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  \
# 0            1.0       0.0     3.0  22.000000    1.0    0.0   7.2500
# 1            2.0       1.0     1.0  38.000000    1.0    0.0  71.2833
# 2            3.0       1.0     3.0  26.000000    0.0    0.0   7.9250
# 3            4.0       1.0     1.0  35.000000    1.0    0.0  53.1000
# 4            5.0       0.0     3.0  35.000000    0.0    0.0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886        887.0       0.0     2.0  27.000000    0.0    0.0  13.0000
# 887        888.0       1.0     1.0  19.000000    0.0    0.0  30.0000
# 888        889.0       0.0     3.0  29.699118    1.0    2.0  23.4500
# 889        890.0       1.0     1.0  26.000000    0.0    0.0  30.0000
# 890        891.0       0.0     3.0  32.000000    0.0    0.0   7.7500
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# ...

# %%
c.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Name           0
# Sex            0
# Ticket         0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# second data sets for handeling  missing values

# %%
hari=pd.read_csv("Covid Live.csv")
hari.head()
# Out:
#    # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths Total\nRecovered  \
# 0  1             USA   98,166,904     1,084,282          NaN       94,962,112
# 1  2           India   44,587,307       528,629          NaN       44,019,095
# 2  3          France   35,342,950       155,078          NaN       34,527,115
# 3  4          Brazil   34,706,757       686,027          NaN       33,838,636
# 4  5         Germany   33,312,373       149,948          NaN       32,315,200
#
#   Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# 0     2,120,510              2,970            293,206           3,239
# 1        39,583                698             31,698             376
# 2       660,757                869            538,892           2,365
# 3       182,094              8,318            161,162           3,186
# 4       847,225              1,406            397,126           1,788
#
#     Total\nTests Tests/\n1M pop     Population
# ...

# %%
hari.isnull().sum()
# Out:
# #                       0
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           5
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
hari.drop(["New\nDeaths"],axis=1,inplace=True)

# %%
hari
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths Total\nRecovered  \
# 0      1             USA   98,166,904     1,084,282       94,962,112
# 1      2           India   44,587,307       528,629       44,019,095
# 2      3          France   35,342,950       155,078       34,527,115
# 3      4          Brazil   34,706,757       686,027       33,838,636
# 4      5         Germany   33,312,373       149,948       32,315,200
# ..   ...             ...          ...           ...              ...
# 225  226            Niue           80           NaN               80
# 226  227    Vatican City           29           NaN               29
# 227  228          Tuvalu           20           NaN              NaN
# 228  229  Western Sahara           10             1                9
# 229  230      MS Zaandam            9             2                7
#
#     Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# ...

# %%
hari.isnull().sum()
# Out:
# #                      0
# Country,\nOther        0
# Total\nCases           0
# Total\nDeaths          5
# Total\nRecovered      16
# Active\nCases         15
# Serious,\nCritical    83
# Tot Cases/\n1M pop     2
# Deaths/\n1M pop        7
# Total\nTests          16
# Tests/\n1M pop        16
# Population             2
# dtype: int64

# %%
hari.to_csv("updatecovid.csv")

# %%
hari1=pd.read_csv("updatecovid.csv",usecols=cat)
hari
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths Total\nRecovered  \
# 0      1             USA   98,166,904     1,084,282       94,962,112
# 1      2           India   44,587,307       528,629       44,019,095
# 2      3          France   35,342,950       155,078       34,527,115
# 3      4          Brazil   34,706,757       686,027       33,838,636
# 4      5         Germany   33,312,373       149,948       32,315,200
# ..   ...             ...          ...           ...              ...
# 225  226            Niue           80           NaN               80
# 226  227    Vatican City           29           NaN               29
# 227  228          Tuvalu           20           NaN              NaN
# 228  229  Western Sahara           10             1                9
# 229  230      MS Zaandam            9             2                7
#
#     Active\nCases Serious,\nCritical Tot Cases/\n1M pop Deaths/\n1M pop  \
# ...

# %%
cat=columns_to_use=['Country,\nOther',
 'Total\nCases',
 'Total\nDeaths',
 'Total\nRecovered',
 'Active\nCases',
 'Serious,\nCritical',
 'Tot Cases/\n1M pop',
 'Deaths/\n1M pop',
 'Total\nTests',
 'Tests/\n1M pop',
 'Population']

# %%
hari1.isnull().sum()
# Out:
# Country,\nOther        0
# Total\nCases           0
# Total\nDeaths          5
# Total\nRecovered      16
# Active\nCases         15
# Serious,\nCritical    83
# Tot Cases/\n1M pop     2
# Deaths/\n1M pop        7
# Total\nTests          16
# Tests/\n1M pop        16
# Population             2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy='most_frequent')

# %%
hari1=sim.fit_transform(hari1)

# %%
hari1
# Out:
# array([['USA', '98,166,904', '1,084,282', ..., '1,118,158,870',
#         '3,339,729', '334,805,269'],
#        ['India', '44,587,307', '528,629', ..., '894,416,853', '635,857',
#         '1,406,631,776'],
#        ['France', '35,342,950', '155,078', ..., '271,490,188',
#         '4,139,547', '65,584,518'],
#        ...,
#        ['Tuvalu', '20', '1', ..., '78,646', '1,023,520', '12,066'],
#        ['Western Sahara', '10', '1', ..., '78,646', '1,023,520',
#         '626,161'],
#        ['MS Zaandam', '9', '2', ..., '78,646', '1,023,520', '1,016,097']],
#       dtype=object)

# %%
a=pd.DataFrame(hari1,columns=cat)
a
# Out:
#     Country,\nOther Total\nCases Total\nDeaths Total\nRecovered Active\nCases  \
# 0               USA   98,166,904     1,084,282       94,962,112     2,120,510
# 1             India   44,587,307       528,629       44,019,095        39,583
# 2            France   35,342,950       155,078       34,527,115       660,757
# 3            Brazil   34,706,757       686,027       33,838,636       182,094
# 4           Germany   33,312,373       149,948       32,315,200       847,225
# ..              ...          ...           ...              ...           ...
# 225            Niue           80             1               80             0
# 226    Vatican City           29             1               29             0
# 227          Tuvalu           20             1        1,006,369            20
# 228  Western Sahara           10             1                9             0
# 229      MS Zaandam            9             2                7             0
#
# ...

# %%
a.isnull().sum()
# Out:
# Country,\nOther       0
# Total\nCases          0
# Total\nDeaths         0
# Total\nRecovered      0
# Active\nCases         0
# Serious,\nCritical    0
# Tot Cases/\n1M pop    0
# Deaths/\n1M pop       0
# Total\nTests          0
# Tests/\n1M pop        0
# Population            0
# dtype: int64

# %% [markdown]
# third datsets for handing missing values

# %%
ros=pd.read_csv("melb_data.csv",usecols=number)
ros
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
number=columns_to_use=['Rooms',
 'Price',
 'Distance',
 'Postcode',
 'Bedroom2',
 'Bathroom',
 'Car',
 'Landsize',
 'BuildingArea',
 'YearBuilt',
 'Lattitude',
 'Longtitude',
 'Propertycount']

# %%
ros.isnull().sum()
# Out:
# Rooms               0
# Price               0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
som=SimpleImputer(strategy='mean')

# %%
ros=som.fit_transform(ros)

# %%
a=pd.DataFrame(ros,columns=number)
a
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0        2.0  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1        2.0  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2        3.0  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3        3.0   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4        4.0  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575    4.0  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576    3.0  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577    3.0  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578    4.0  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579    4.0  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea    YearBuilt  Lattitude  Longtitude  \
# 0         202.0     151.96765  1964.684217  -37.79960   144.99840
# ...

# %%
a.isnull().sum()
# Out:
# Rooms            0
# Price            0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Lattitude        0
# Longtitude       0
# Propertycount    0
# dtype: int64

# %%
ros1=pd.read_csv("melb_data.csv",usecols=cat)
ros1
# Out:
#               Suburb           Address Type Method   SellerG        Date  \
# 0         Abbotsford      85 Turner St    h      S    Biggin   3/12/2016
# 1         Abbotsford   25 Bloomburg St    h      S    Biggin   4/02/2016
# 2         Abbotsford      5 Charles St    h     SP    Biggin   4/03/2017
# 3         Abbotsford  40 Federation La    h     PI    Biggin   4/03/2017
# 4         Abbotsford       55a Park St    h     VB    Nelson   4/06/2016
# ...              ...               ...  ...    ...       ...         ...
# 13575  Wheelers Hill      12 Strada Cr    h      S     Barry  26/08/2017
# 13576   Williamstown     77 Merrett Dr    h     SP  Williams  26/08/2017
# 13577   Williamstown       83 Power St    h      S     Raine  26/08/2017
# 13578   Williamstown      96 Verdon St    h     PI   Sweeney  26/08/2017
# 13579     Yarraville        6 Agnes St    h     SP   Village  26/08/2017
#
#       CouncilArea                  Regionname
# ...

# %%
cat=columns_to_use=['Suburb',
 'Address',
 'Type',
 'Method',
 'SellerG',
 'Date',
 'CouncilArea',
 'Regionname']

# %%
from sklearn.impute import SimpleImputer
reg=SimpleImputer(strategy='most_frequent')

# %%
ros1=reg.fit_transform(ros1)

# %%
b=pd.DataFrame(ros1,columns=cat)

# %%
b
# Out:
#               Suburb           Address Type Method   SellerG        Date  \
# 0         Abbotsford      85 Turner St    h      S    Biggin   3/12/2016
# 1         Abbotsford   25 Bloomburg St    h      S    Biggin   4/02/2016
# 2         Abbotsford      5 Charles St    h     SP    Biggin   4/03/2017
# 3         Abbotsford  40 Federation La    h     PI    Biggin   4/03/2017
# 4         Abbotsford       55a Park St    h     VB    Nelson   4/06/2016
# ...              ...               ...  ...    ...       ...         ...
# 13575  Wheelers Hill      12 Strada Cr    h      S     Barry  26/08/2017
# 13576   Williamstown     77 Merrett Dr    h     SP  Williams  26/08/2017
# 13577   Williamstown       83 Power St    h      S     Raine  26/08/2017
# 13578   Williamstown      96 Verdon St    h     PI   Sweeney  26/08/2017
# 13579     Yarraville        6 Agnes St    h     SP   Village  26/08/2017
#
#       CouncilArea                  Regionname
# ...

# %%
b.isnull().sum()
# Out:
# Suburb         0
# Address        0
# Type           0
# Method         0
# SellerG        0
# Date           0
# CouncilArea    0
# Regionname     0
# dtype: int64

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0        2.0  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1        2.0  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2        3.0  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3        3.0   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4        4.0  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575    4.0  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576    3.0  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577    3.0  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578    4.0  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579    4.0  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea    YearBuilt  ...  Longtitude  Propertycount  \
# ...

# %%
c.isnull().sum()
# Out:
# Rooms            0
# Price            0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Lattitude        0
# Longtitude       0
# Propertycount    0
# Suburb           0
# Address          0
# Type             0
# Method           0
# SellerG          0
# Date             0
# CouncilArea      0
# Regionname       0
# dtype: int64

# %% [markdown]
# fourth dataset to fill the missing value in weather datsets

# %%
reg=pd.read_csv("weather_2012.csv",usecols=numbers)
reg
# Out:
#      Unnamed: 0  month  day  temp_dailyMin  temp_minGround  temp_dailyMean  \
# 0             0      1    1            0.8            -1.2             2.2
# 1             1      1    2            0.4             0.4             2.1
# 2             2      1    3            3.3             2.7             6.6
# 3             3      1    4            3.6             1.0             7.2
# 4             4      1    5            4.3             2.3             6.7
# ..          ...    ...  ...            ...             ...             ...
# 361         361     12   27            3.4            -0.3             7.6
# 362         362     12   28            1.1            -0.1             4.8
# 363         363     12   29           -2.9            -5.2             0.2
# 364         364     12   30           -2.1            -4.5             0.5
# 365         365     12   31           -2.0            -4.6             2.2
#
# ...

# %%
reg.isnull().sum()
# Out:
# Unnamed: 0         0
# month              0
# day                0
# temp_dailyMin      0
# temp_minGround     0
# temp_dailyMean     0
# temp_dailyMax      0
# temp_7h           18
# temp_14h          18
# temp_19h          18
# hum_dailyMean      0
# hum_7h            18
# hum_14h           18
# hum_19h           18
# sun_hours          2
# skyCover_7h        2
# skyCover_14h       2
# skyCover_19h       2
# wind_degrees       2
# wind_mSec          2
# precip             0
# year               0
# dtype: int64

# %% [raw]
# numbers=columns_to_use=['Unnamed: 0',
#  'month',
#  'day',
#  'temp_dailyMin',
#  'temp_minGround',
#  'temp_dailyMean',
#  'temp_dailyMax',
#  'temp_7h',
#  'temp_14h',
#  'temp_19h',
#  'hum_dailyMean',
#  'hum_7h',
#  'hum_14h',
#  'hum_19h',
#  'sun_hours',
#  'skyCover_7h',
#  'skyCover_14h',
#  'skyCover_19h',
#  'wind_degrees',
#  'wind_mSec',
#  'precip',
#  'year']

# %%
from sklearn.impute import SimpleImputer
sig=SimpleImputer(strategy="most_frequent")

# %%
reg=sig.fit_transform(reg)

# %%
a=pd.DataFrame(reg,columns=numbers)

# %%
a
# Out:
#      Unnamed: 0  month   day  temp_dailyMin  temp_minGround  temp_dailyMean  \
# 0           0.0    1.0   1.0            0.8            -1.2             2.2
# 1           1.0    1.0   2.0            0.4             0.4             2.1
# 2           2.0    1.0   3.0            3.3             2.7             6.6
# 3           3.0    1.0   4.0            3.6             1.0             7.2
# 4           4.0    1.0   5.0            4.3             2.3             6.7
# ..          ...    ...   ...            ...             ...             ...
# 361       361.0   12.0  27.0            3.4            -0.3             7.6
# 362       362.0   12.0  28.0            1.1            -0.1             4.8
# 363       363.0   12.0  29.0           -2.9            -5.2             0.2
# 364       364.0   12.0  30.0           -2.1            -4.5             0.5
# 365       365.0   12.0  31.0           -2.0            -4.6             2.2
#
# ...

# %%
a.isnull().sum()
# Out:
# Unnamed: 0        0
# month             0
# day               0
# temp_dailyMin     0
# temp_minGround    0
# temp_dailyMean    0
# temp_dailyMax     0
# temp_7h           0
# temp_14h          0
# temp_19h          0
# hum_dailyMean     0
# hum_7h            0
# hum_14h           0
# hum_19h           0
# sun_hours         0
# skyCover_7h       0
# skyCover_14h      0
# skyCover_19h      0
# wind_degrees      0
# wind_mSec         0
# precip            0
# year              0
# dtype: int64

# %% [markdown]
# fifth datasets for handling missing values

# %%
import pandas as pd
sas=pd.read_csv("cleandata.csv",usecols=number)
sas
# Out:
#       AgeStart  AgeEnd  HeightStart  HeightEnd
# 0           16      17        122.0      183.0
# 1           19      20        153.0      183.0
# 2           19      20        153.0      183.0
# 3           24      25        153.0      183.0
# 4           21      22        153.0      183.0
# ...        ...     ...          ...        ...
# 2122        24      25        153.0      275.0
# 2123        15      16        153.0       31.0
# 2124        15      16        153.0      214.0
# 2125        58      59        153.0       31.0
# 2126         5       7          NaN        NaN
#
# [2127 rows x 4 columns]

# %%
sas.drop("Date",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23808/2923686197.py in <module>
# ----> 1 sas.drop("Date",axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
sas.isnull().sum()
# Out:
# AgeStart        0
# AgeEnd          0
# HeightStart    33
# HeightEnd      33
# dtype: int64

# %%
number=columns_to_use=['AgeStart', 'AgeEnd', 'HeightStart', 'HeightEnd']

# %%
from sklearn.impute import SimpleImputer
see=SimpleImputer(strategy="mean")

# %%
sas=see.fit_transform(sas)

# %%
a=pd.DataFrame(sas,columns=number)

# %%
a
# Out:
#       AgeStart  AgeEnd  HeightStart   HeightEnd
# 0         16.0    17.0     122.0000  183.000000
# 1         19.0    20.0     153.0000  183.000000
# 2         19.0    20.0     153.0000  183.000000
# 3         24.0    25.0     153.0000  183.000000
# 4         21.0    22.0     153.0000  183.000000
# ...        ...     ...          ...         ...
# 2122      24.0    25.0     153.0000  275.000000
# 2123      15.0    16.0     153.0000   31.000000
# 2124      15.0    16.0     153.0000  214.000000
# 2125      58.0    59.0     153.0000   31.000000
# 2126       5.0     7.0     168.5234  176.548233
#
# [2127 rows x 4 columns]

# %%
a.isnull().sum()
# Out:
# AgeStart       0
# AgeEnd         0
# HeightStart    0
# HeightEnd      0
# dtype: int64

# %%
cat=columns_to_use=['Name', 'Gender', 'Relative', 'Address', 'Built', 'Dist', 'State']

# %%
sas1=pd.read_csv("cleandata.csv",usecols=cat)
sas1
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                        NaN    Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL      NaN   SUMA N GHOSHAL
# 2124                     NaN    Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address         Built  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...  normalmedium
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...          thin
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...          thin
# ...

# %%
sas1.isnull().sum()
# Out:
# Name        567
# Gender      117
# Relative      2
# Address       0
# Built        12
# Dist          0
# State       131
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
reg=SimpleImputer(strategy="most_frequent")

# %%
sas1=reg.fit_transform(sas1)

# %%
b=pd.DataFrame(sas1,columns=cat)

# %%
b
# Out:
#                         Name  Gender          Relative  \
# 0                      JYOTI  Female             GEETA
# 1                   ABHISHEK    Male      MUKE SHKUMAR
# 2                    Female     Male      RAJE SHKUMAR
# 3                 JAIPRAKASH    Male     KAMA LKISHORE
# 4                     SADDAM    Male            MUNN A
# ...                      ...     ...               ...
# 2122                  MANOJ     Male    SURE SH KUMAR
# 2123           SAGARGHOSHAL     Male   SUMA N GHOSHAL
# 2124                 Female     Male    PARM OD KUMAR
# 2125  CHANDER NARYAN PANDEY     Male         KULD EEP
# 2126                  DEPTY     Male        RAM AVTAR
#
#                                                 Address         Built  \
# 0     ,  , E 129 A SHOK NAGAR PRIDAY MARKET CHOWK DE...  normalmedium
# 1     , , JHUGGI NO. N- 78/102, SHIVANAND SCHOOL SEW...          thin
# 2     , NO, 79, GALI NO. 3 KONDLI DELHI NEW A SHOK N...          thin
# ...

# %%
b.isnull().sum()
# Out:
# Name        0
# Gender      0
# Relative    0
# Address     0
# Built       0
# Dist        0
# State       0
# dtype: int64

# %% [markdown]
# sixth dataset for handling missing values

# %%
hari=pd.read_csv("Flipkart_Mobiles.csv",usecols=number)
hari
# Out:
#       Rating  Selling Price  Original Price
# 0        4.5          11990           15990
# 1        4.5          11990           15990
# 2        4.3          13990           17990
# 3        4.3          13990           17990
# 4        4.5          11990           15990
# ...      ...            ...             ...
# 3109     4.3          25990           25990
# 3110     4.3          25489           28449
# 3111     4.3          27239           31489
# 3112     4.2          22989           22989
# 3113     4.2          20350           22595
#
# [3114 rows x 3 columns]

# %%
hari.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             43
# Storage            39
# Rating            144
# Selling Price       0
# Original Price      0
# dtype: int64

# %%
number=columns_to_use=['Rating', 'Selling Price', 'Original Price']

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy="mean")

# %%
hari=sim.fit_transform(hari)

# %%
a=pd.DataFrame(hari,columns=number)

# %%
a
# Out:
#       Rating  Selling Price  Original Price
# 0        4.5        11990.0         15990.0
# 1        4.5        11990.0         15990.0
# 2        4.3        13990.0         17990.0
# 3        4.3        13990.0         17990.0
# 4        4.5        11990.0         15990.0
# ...      ...            ...             ...
# 3109     4.3        25990.0         25990.0
# 3110     4.3        25489.0         28449.0
# 3111     4.3        27239.0         31489.0
# 3112     4.2        22989.0         22989.0
# 3113     4.2        20350.0         22595.0
#
# [3114 rows x 3 columns]

# %%
a.isnull().sum()
# Out:
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64

# %%
hari1=pd.read_csv("Flipkart_Mobiles.csv",usecols=cat)
hari1
# Out:
#         Brand   Model            Color Memory Storage
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB
# 1        OPPO     A53       Mint Cream   4 GB   64 GB
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB
# 3        OPPO     A53       Mint Cream   6 GB  128 GB
# 4        OPPO     A53   Electric Black   4 GB   64 GB
# ...       ...     ...              ...    ...     ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB
#
# [3114 rows x 5 columns]

# %%
hari1.isnull().sum()
# Out:
# Brand       0
# Model       0
# Color       0
# Memory     43
# Storage    39
# dtype: int64

# %%
cat=columns_to_use=['Brand', 'Model', 'Color', 'Memory', 'Storage']

# %%
from sklearn.impute import SimpleImputer
seg=SimpleImputer(strategy="most_frequent")

# %%
hari1=seg.fit_transform(hari1)

# %%
b=pd.DataFrame(hari1,columns=cat)
b
# Out:
#         Brand   Model            Color Memory Storage
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB
# 1        OPPO     A53       Mint Cream   4 GB   64 GB
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB
# 3        OPPO     A53       Mint Cream   6 GB  128 GB
# 4        OPPO     A53   Electric Black   4 GB   64 GB
# ...       ...     ...              ...    ...     ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB
#
# [3114 rows x 5 columns]

# %%
b.isnull().sum()
# Out:
# Brand      0
# Model      0
# Color      0
# Memory     0
# Storage    0
# dtype: int64

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#       Rating  Selling Price  Original Price    Brand   Model            Color  \
# 0        4.5        11990.0         15990.0     OPPO     A53  Moonlight Black
# 1        4.5        11990.0         15990.0     OPPO     A53       Mint Cream
# 2        4.3        13990.0         17990.0     OPPO     A53  Moonlight Black
# 3        4.3        13990.0         17990.0     OPPO     A53       Mint Cream
# 4        4.5        11990.0         15990.0     OPPO     A53   Electric Black
# ...      ...            ...             ...      ...     ...              ...
# 3109     4.3        25990.0         25990.0  SAMSUNG  M52 5G    Blazing Black
# 3110     4.3        25489.0         28449.0  SAMSUNG  M52 5G         Icy Blue
# 3111     4.3        27239.0         31489.0  SAMSUNG  M52 5G         Icy Blue
# 3112     4.2        22989.0         22989.0  SAMSUNG  M52 5G      Slate Black
# 3113     4.2        20350.0         22595.0  SAMSUNG  M52 5G         Sky Blue
#
#      Memory Storage
# ...

# %%
c.isnull().sum()
# Out:
# Rating            0
# Selling Price     0
# Original Price    0
# Brand             0
# Model             0
# Color             0
# Memory            0
# Storage           0
# dtype: int64

# %% [markdown]
# seventh data set for handling the missing values

# %%
ros=pd.read_csv("Airbnb_Open_Data.csv",usecols=number)
ros
# Out:
#              id      host id       lat      long  Construction year  \
# 0       1001254  80014485718  40.64749 -73.97237             2020.0
# 1       1002102  52335172823  40.75362 -73.98377             2007.0
# 2       1002403  78829239556  40.80902 -73.94190             2005.0
# 3       1002755  85098326012  40.68514 -73.95976             2005.0
# 4       1003689  92037596077  40.79851 -73.94399             2009.0
# ...         ...          ...       ...       ...                ...
# 102594  6092437  12312296767  40.70862 -73.94651             2003.0
# 102595  6092990  77864383453  40.80460 -73.96545             2016.0
# 102596  6093542  69050334417  40.67505 -73.98045             2009.0
# 102597  6094094  11160591270  40.74989 -73.93777             2015.0
# 102598  6094647  68170633372  40.76807 -73.98342             2010.0
#
#         minimum nights  number of reviews  reviews per month  \
# 0                 10.0                9.0               0.21
# ...

# %%
ros.isnull().sum()
# Out:
# id                                    0
# host id                               0
# lat                                   8
# long                                  8
# Construction year                   214
# minimum nights                      409
# number of reviews                   183
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# dtype: int64

# %%
number=columns_to_use=['id',
 'host id',
 'lat',
 'long',
 'Construction year',
 'minimum nights',
 'number of reviews',
 'reviews per month',
 'review rate number',
 'calculated host listings count',
 'availability 365']

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy="most_frequent")

# %%
ros=sim.fit_transform(ros)

# %%
a=pd.DataFrame(ros,columns=number)
a
# Out:
#                id       host id       lat      long  Construction year  \
# 0       1001254.0  8.001449e+10  40.64749 -73.97237             2020.0
# 1       1002102.0  5.233517e+10  40.75362 -73.98377             2007.0
# 2       1002403.0  7.882924e+10  40.80902 -73.94190             2005.0
# 3       1002755.0  8.509833e+10  40.68514 -73.95976             2005.0
# 4       1003689.0  9.203760e+10  40.79851 -73.94399             2009.0
# ...           ...           ...       ...       ...                ...
# 102594  6092437.0  1.231230e+10  40.70862 -73.94651             2003.0
# 102595  6092990.0  7.786438e+10  40.80460 -73.96545             2016.0
# 102596  6093542.0  6.905033e+10  40.67505 -73.98045             2009.0
# 102597  6094094.0  1.116059e+10  40.74989 -73.93777             2015.0
# 102598  6094647.0  6.817063e+10  40.76807 -73.98342             2010.0
#
#         minimum nights  number of reviews  reviews per month  \
# ...

# %%
a.isnull().sum()
# Out:
# id                                0
# host id                           0
# lat                               0
# long                              0
# Construction year                 0
# minimum nights                    0
# number of reviews                 0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# dtype: int64

# %%
ros1=pd.read_csv("Airbnb_Open_Data.csv",usecols=cat)
ros1
# Out:
# C:\Users\harih\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                     NAME  \
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                    NaN
# 4       Entire Apt: Spacious Studio/Loft by central park
# ...                                                  ...
# 102594                        Spare room in Williamsburg
# 102595                     Best Location near Columbia U
# 102596                    Comfy, bright room in Brooklyn
# 102597                  Big Studio-One Stop from Midtown
# 102598                              585 sf Luxury Studio
#
# ...

# %%
ros1.isnull().sum()
# Out:
# NAME                         250
# host_identity_verified       289
# host name                    406
# neighbourhood group           29
# neighbourhood                 16
# country                      532
# country code                 131
# instant_bookable             105
# cancellation_policy           76
# room type                      0
# price                        247
# service fee                  273
# last review                15893
# house_rules                52131
# license                   102597
# dtype: int64

# %%
cat=columns_to_use=['NAME',
 'host_identity_verified',
 'host name',
 'neighbourhood group',
 'neighbourhood',
 'country',
 'country code',
 'instant_bookable',
 'cancellation_policy',
 'room type',
 'price',
 'service fee',
 'last review',
 'house_rules',
 'license']

# %%
from sklearn.impute import SimpleImputer
seg=SimpleImputer(strategy="most_frequent")

# %%
ros1=seg.fit_transform(ros1)

# %%
b=pd.DataFrame(ros1,columns=cat)
b
# Out:
#                                                     NAME  \
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                                    Home away from home
# 4       Entire Apt: Spacious Studio/Loft by central park
# ...                                                  ...
# 102594                        Spare room in Williamsburg
# 102595                     Best Location near Columbia U
# 102596                    Comfy, bright room in Brooklyn
# 102597                  Big Studio-One Stop from Midtown
# 102598                              585 sf Luxury Studio
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 2                 unconfirmed        Elise           Manhattan
# ...

# %%
b.isnull().sum()
# Out:
# NAME                      0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# price                     0
# service fee               0
# last review               0
# house_rules               0
# license                   0
# dtype: int64

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#                id       host id       lat      long  Construction year  \
# 0       1001254.0  8.001449e+10  40.64749 -73.97237             2020.0
# 1       1002102.0  5.233517e+10  40.75362 -73.98377             2007.0
# 2       1002403.0  7.882924e+10  40.80902 -73.94190             2005.0
# 3       1002755.0  8.509833e+10  40.68514 -73.95976             2005.0
# 4       1003689.0  9.203760e+10  40.79851 -73.94399             2009.0
# ...           ...           ...       ...       ...                ...
# 102594  6092437.0  1.231230e+10  40.70862 -73.94651             2003.0
# 102595  6092990.0  7.786438e+10  40.80460 -73.96545             2016.0
# 102596  6093542.0  6.905033e+10  40.67505 -73.98045             2009.0
# 102597  6094094.0  1.116059e+10  40.74989 -73.93777             2015.0
# 102598  6094647.0  6.817063e+10  40.76807 -73.98342             2010.0
#
#         minimum nights  number of reviews  reviews per month  \
# ...

# %%
c.isnull().sum()
# Out:
# id                                0
# host id                           0
# lat                               0
# long                              0
# Construction year                 0
# minimum nights                    0
# number of reviews                 0
# reviews per month                 0
# review rate number                0
# calculated host listings count    0
# availability 365                  0
# NAME                              0
# host_identity_verified            0
# host name                         0
# neighbourhood group               0
# neighbourhood                     0
# country                           0
# country code                      0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# price                             0
# service fee                       0
# last review                       0
# house_rules                       0
# license                           0
# ...

# %% [markdown]
# eight dataset for handling thre missing values

# %%
reg=pd.read_csv("COVID_BG.csv",usecols=number)
reg
# Out:
#            Date  Performed_Tests  Total_tests_per_thousand  Daily_Tests  \
# 0    2020-03-08              NaN                       NaN          NaN
# 1    2020-03-09              NaN                       NaN          NaN
# 2    2020-03-10              NaN                       NaN          NaN
# 3    2020-03-11              NaN                       NaN          NaN
# 4    2020-03-12              NaN                       NaN          NaN
# ..          ...              ...                       ...          ...
# 442  2021-05-24        2749884.0                   395.755       6716.0
# 443  2021-05-25        2754463.0                   396.414       4550.0
# 444  2021-05-26        2768262.0                   398.400      13839.0
# 445  2021-05-27        2782132.0                   400.396      13872.0
# 446  2021-05-28        2795296.0                   402.291      13164.0
#
#      New_tests_per_thousand  Confirmed_cases  Total_cases_per_million  \
# ...

# %%
reg.isnull().sum()
# Out:
# Date                                     0
# Performed_Tests                         51
# Total_tests_per_thousand                86
# Daily_Tests                             90
# New_tests_per_thousand                 118
# Confirmed_cases                          0
# Total_cases_per_million                  0
# Active_cases                            90
# New_daily_cases                          0
# New_cases_per_million                    0
# Positive_rate                           42
# Hospitalized                            29
# Hosp_patients_per_million               34
# In_ICU                                  29
# ICU_patients_per_million                34
# Recovered                               90
# Daily_recovered                         90
# Deaths                                   0
# Total_deaths_per_million                 0
# Daily_deaths                             0
# New_deaths_per_million                   0
# Reproduction_rate                       14
# ...

# %%
number=columns_to_use=['Date',
 'Performed_Tests',
 'Total_tests_per_thousand',
 'Daily_Tests',
 'New_tests_per_thousand',
 'Confirmed_cases',
 'Total_cases_per_million',
 'Active_cases',
 'New_daily_cases',
 'New_cases_per_million',
 'Positive_rate',
 'Hospitalized',
 'Hosp_patients_per_million',
 'In_ICU',
 'ICU_patients_per_million',
 'Recovered',
 'Daily_recovered',
 'Deaths',
 'Total_deaths_per_million',
 'Daily_deaths',
 'New_deaths_per_million',
 'Reproduction_rate',
 'Total_vaccinations',
 'People_vaccinated',
 'People_fully_vaccinated',
 'New_vaccinations',
 'Total_vaccinations_per_hundred',
 'People_vaccinated_per_hundred',
 'People_fully_vaccinated_per_hundred']

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy="most_frequent")

# %%
reg=sim.fit_transform(reg)

# %%
a=pd.DataFrame(reg,columns=number)
a
# Out:
#            Date Performed_Tests Total_tests_per_thousand Daily_Tests  \
# 0    2020-03-08         90329.0                    2.663      2775.0
# 1    2020-03-09         90329.0                    2.663      2775.0
# 2    2020-03-10         90329.0                    2.663      2775.0
# 3    2020-03-11         90329.0                    2.663      2775.0
# 4    2020-03-12         90329.0                    2.663      2775.0
# ..          ...             ...                      ...         ...
# 442  2021-05-24       2749884.0                  395.755      6716.0
# 443  2021-05-25       2754463.0                  396.414      4550.0
# 444  2021-05-26       2768262.0                    398.4     13839.0
# 445  2021-05-27       2782132.0                  400.396     13872.0
# 446  2021-05-28       2795296.0                  402.291     13164.0
#
#     New_tests_per_thousand Confirmed_cases Total_cases_per_million  \
# 0                    0.167               4                   0.576
# ...

# %%
a.isnull().sum()
# Out:
# Date                                   0
# Performed_Tests                        0
# Total_tests_per_thousand               0
# Daily_Tests                            0
# New_tests_per_thousand                 0
# Confirmed_cases                        0
# Total_cases_per_million                0
# Active_cases                           0
# New_daily_cases                        0
# New_cases_per_million                  0
# Positive_rate                          0
# Hospitalized                           0
# Hosp_patients_per_million              0
# In_ICU                                 0
# ICU_patients_per_million               0
# Recovered                              0
# Daily_recovered                        0
# Deaths                                 0
# Total_deaths_per_million               0
# Daily_deaths                           0
# New_deaths_per_million                 0
# Reproduction_rate                      0
# Total_vaccinations                     0
# ...

# %% [markdown]
# nineth data set for handling the missing values

# %%
sim=pd.read_csv("aug_train.csv",usecols=number)
sim
# Out:
#        enrollee_id  city_development_index  training_hours  target
# 0             8949                   0.920              36     1.0
# 1            29725                   0.776              47     0.0
# 2            11561                   0.624              83     0.0
# 3            33241                   0.789              52     1.0
# 4              666                   0.767               8     0.0
# ...            ...                     ...             ...     ...
# 19153         7386                   0.878              42     1.0
# 19154        31398                   0.920              52     1.0
# 19155        24576                   0.920              44     0.0
# 19156         5756                   0.802              97     0.0
# 19157        23834                   0.855             127     0.0
#
# [19158 rows x 4 columns]

# %%
sim.isnull().sum()
# Out:
# enrollee_id               0
# city_development_index    0
# training_hours            0
# target                    0
# dtype: int64

# %%
number=columns_to_use=['enrollee_id', 'city_development_index', 'training_hours', 'target']

# %%
sim1=pd.read_csv("aug_train.csv",usecols=cat)
sim1
# Out:
#            city gender      relevent_experience enrolled_university  \
# 0      city_103   Male  Has relevent experience       no_enrollment
# 1       city_40   Male   No relevent experience       no_enrollment
# 2       city_21    NaN   No relevent experience    Full time course
# 3      city_115    NaN   No relevent experience                 NaN
# 4      city_162   Male  Has relevent experience       no_enrollment
# ...         ...    ...                      ...                 ...
# 19153  city_173   Male   No relevent experience       no_enrollment
# 19154  city_103   Male  Has relevent experience       no_enrollment
# 19155  city_103   Male  Has relevent experience       no_enrollment
# 19156   city_65   Male  Has relevent experience       no_enrollment
# 19157   city_67    NaN   No relevent experience       no_enrollment
#
#       education_level major_discipline experience company_size  \
# 0            Graduate             STEM        >20          NaN
# ...

# %%
cat=columns_to_use=['city',
 'gender',
 'relevent_experience',
 'enrolled_university',
 'education_level',
 'major_discipline',
 'experience',
 'company_size',
 'company_type',
 'last_new_job']

# %%
sim1.isnull().sum()
# Out:
# city                      0
# gender                 4508
# relevent_experience       0
# enrolled_university     386
# education_level         460
# major_discipline       2813
# experience               65
# company_size           5938
# company_type           6140
# last_new_job            423
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
sam=SimpleImputer(strategy="most_frequent")

# %%
sim1=sam.fit_transform(sim1)

# %%
a=pd.DataFrame(sim1,columns=cat)
a
# Out:
#            city gender      relevent_experience enrolled_university  \
# 0      city_103   Male  Has relevent experience       no_enrollment
# 1       city_40   Male   No relevent experience       no_enrollment
# 2       city_21   Male   No relevent experience    Full time course
# 3      city_115   Male   No relevent experience       no_enrollment
# 4      city_162   Male  Has relevent experience       no_enrollment
# ...         ...    ...                      ...                 ...
# 19153  city_173   Male   No relevent experience       no_enrollment
# 19154  city_103   Male  Has relevent experience       no_enrollment
# 19155  city_103   Male  Has relevent experience       no_enrollment
# 19156   city_65   Male  Has relevent experience       no_enrollment
# 19157   city_67   Male   No relevent experience       no_enrollment
#
#       education_level major_discipline experience company_size  \
# 0            Graduate             STEM        >20        50-99
# ...

# %%
b=pd.concat([sim,a],axis=1)
b
# Out:
#        enrollee_id  city_development_index  training_hours  target      city  \
# 0             8949                   0.920              36     1.0  city_103
# 1            29725                   0.776              47     0.0   city_40
# 2            11561                   0.624              83     0.0   city_21
# 3            33241                   0.789              52     1.0  city_115
# 4              666                   0.767               8     0.0  city_162
# ...            ...                     ...             ...     ...       ...
# 19153         7386                   0.878              42     1.0  city_173
# 19154        31398                   0.920              52     1.0  city_103
# 19155        24576                   0.920              44     0.0  city_103
# 19156         5756                   0.802              97     0.0   city_65
# 19157        23834                   0.855             127     0.0   city_67
#
# ...

# %%
b.isnull().sum()
# Out:
# enrollee_id               0
# city_development_index    0
# training_hours            0
# target                    0
# city                      0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# dtype: int64

# %% [markdown]
# tenth data sets to handle the missing values

# %%
nar=pd.read_csv("Video_Game_Sales_as_of_Jan_2017.csv",usecols=number)
nar
# Out:
#        Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0               2006.0     41.36     28.96      3.77         8.45
# 1               1985.0     29.08      3.58      6.81         0.77
# 2               2008.0     15.68     12.80      3.79         3.29
# 3               2009.0     15.61     10.95      3.28         2.95
# 4               1996.0     11.27      8.89     10.22         1.00
# ...                ...       ...       ...       ...          ...
# 17411           2007.0      0.00      0.00      0.00         0.00
# 17412           2007.0      0.00      0.00      0.00         0.00
# 17413           2002.0      0.00      0.00      0.01         0.00
# 17414           2009.0      0.00      0.00      0.01         0.00
# 17415           2007.0      0.00      0.00      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 0             82.54          76.0          51.0         8.0       324.0
# ...

# %%
nar.isnull().sum()
# Out:
# Year_of_Release       8
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       9080
# Critic_Count       9080
# User_Score         9618
# User_Count         9618
# dtype: int64

# %%
number=columns_to_use=['Year_of_Release',
 'NA_Sales',
 'EU_Sales',
 'JP_Sales',
 'Other_Sales',
 'Global_Sales',
 'Critic_Score',
 'Critic_Count',
 'User_Score',
 'User_Count']

# %%
from sklearn.impute import SimpleImputer
seg=SimpleImputer(strategy="mean")

# %%
nar=seg.fit_transform(nar)

# %%
a=pd.DataFrame(nar,columns=number)
a
# Out:
#        Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0               2006.0     41.36     28.96      3.77         8.45
# 1               1985.0     29.08      3.58      6.81         0.77
# 2               2008.0     15.68     12.80      3.79         3.29
# 3               2009.0     15.61     10.95      3.28         2.95
# 4               1996.0     11.27      8.89     10.22         1.00
# ...                ...       ...       ...       ...          ...
# 17411           2007.0      0.00      0.00      0.00         0.00
# 17412           2007.0      0.00      0.00      0.00         0.00
# 17413           2002.0      0.00      0.00      0.01         0.00
# 17414           2009.0      0.00      0.00      0.01         0.00
# 17415           2007.0      0.00      0.00      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 0             82.54     76.000000     51.000000    8.000000   324.00000
# ...

# %%
nar1=pd.read_csv("Video_Game_Sales_as_of_Jan_2017.csv",usecols=cat)
nar1
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue        G
# ...                                                 ...      ...
# 17411  Nancy Drew: The Deadly Secret of Olde World Park       DS
# 17412                      Fashion Designer: Style Icon       DS
# 17413            Ashita no Joe 2: The Anime Super Remix      PS2
# 17414            NadePro!! Kisama no Seiyuu Yatte Miro!      PS2
# 17415                     Brian Lara 2007 Pressure Play      PSP
#
#               Genre              Publisher Rating
# 0            Sports               Nintendo      E
# 1          Platform               Nintendo    NaN
# ...

# %%
cat=columns_to_use=['Name', 'Platform', 'Genre', 'Publisher', 'Rating']

# %%
nar1.isnull().sum()
# Out:
# Name            0
# Platform        0
# Genre           0
# Publisher       1
# Rating       7164
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy="most_frequent")

# %%
nar1=sim.fit_transform(nar1)

# %%
b=pd.DataFrame(nar1,columns=cat)
b
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue        G
# ...                                                 ...      ...
# 17411  Nancy Drew: The Deadly Secret of Olde World Park       DS
# 17412                      Fashion Designer: Style Icon       DS
# 17413            Ashita no Joe 2: The Anime Super Remix      PS2
# 17414            NadePro!! Kisama no Seiyuu Yatte Miro!      PS2
# 17415                     Brian Lara 2007 Pressure Play      PSP
#
#               Genre              Publisher Rating
# 0            Sports               Nintendo      E
# 1          Platform               Nintendo      E
# ...

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#        Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0               2006.0     41.36     28.96      3.77         8.45
# 1               1985.0     29.08      3.58      6.81         0.77
# 2               2008.0     15.68     12.80      3.79         3.29
# 3               2009.0     15.61     10.95      3.28         2.95
# 4               1996.0     11.27      8.89     10.22         1.00
# ...                ...       ...       ...       ...          ...
# 17411           2007.0      0.00      0.00      0.00         0.00
# 17412           2007.0      0.00      0.00      0.00         0.00
# 17413           2002.0      0.00      0.00      0.01         0.00
# 17414           2009.0      0.00      0.00      0.01         0.00
# 17415           2007.0      0.00      0.00      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 0             82.54     76.000000     51.000000    8.000000   324.00000
# ...

# %%
c.isnull().sum()
# Out:
# Year_of_Release    0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Name               0
# Platform           0
# Genre              0
# Publisher          0
# Rating             0
# dtype: int64
